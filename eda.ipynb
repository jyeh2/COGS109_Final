# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the saved file
combined = pd.read_csv("combined_events.csv")

# %%
combined
# Out:
#     A.S. Advertisement Pass          Location_Type  \
# 0                        No  Mandeville Auditorium
# 1                        No  Mandeville Auditorium
# 2                        No          Pepper Canyon
# 3                        No           Price Center
# 4                        No           Price Center
# ..                      ...                    ...
# 590                     NaN                 Warren
# 591                     NaN           Price Center
# 592                     NaN                Revelle
# 593               Not Found           Price Center
# 594               Not Found  Mandeville Auditorium
#
#                                VENUE  AWARDED  Attendance_Ratio        DATE  \
# 0           Student Center Courtyard   587.24            0.4598  2024-09-24
# 1                  Multipurpose Room  1752.15            0.5422  2024-09-24
# 2        Epstein Family Amphitheater  7931.74            0.0000  2024-09-24
# ...
